# %%
#Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
color = sns.color_palette()

# %% [markdown]
# #### Reading the dataset

# %%
train = pd.read_csv('../Data_Science_Practice_Files/intercampusai2019/train.csv')
print("The number of row and column in the dataset is :", train.shape)
# Out:
# The number of row and column in the dataset is : (38312, 19)

# %%
#We can see the first set of rows contained in the data
train.head()
# Out:
#     EmployeeNo                               Division        Qualification  \
# 0  YAK/S/00001         Commercial Sales and Marketing     MSc, MBA and PhD
# 1  YAK/S/00002  Customer Support and Field Operations  First Degree or HND
# 2  YAK/S/00003         Commercial Sales and Marketing  First Degree or HND
# 3  YAK/S/00004         Commercial Sales and Marketing  First Degree or HND
# 4  YAK/S/00006               Information and Strategy  First Degree or HND
#
#    Gender   Channel_of_Recruitment  Trainings_Attended  Year_of_birth  \
# 0  Female  Direct Internal process                   2           1986
# 1    Male        Agency and others                   2           1991
# 2    Male  Direct Internal process                   2           1987
# 3    Male        Agency and others                   3           1982
# 4    Male  Direct Internal process                   3           1990
#
#    Last_performance_score  Year_of_recruitment  Targets_met  Previous_Award  \
# ...

# %%
#We can see the last set of rows contained in the data
train.tail()
# Out:
#         EmployeeNo                                     Division  \
# 38307  YAK/S/54802  Information Technology and Solution Support
# 38308  YAK/S/54805        Customer Support and Field Operations
# 38309  YAK/S/54806                     Information and Strategy
# 38310  YAK/S/54807               Commercial Sales and Marketing
# 38311  YAK/S/54808                         People/HR Management
#
#              Qualification  Gender   Channel_of_Recruitment  \
# 38307  First Degree or HND  Female  Direct Internal process
# 38308     MSc, MBA and PhD  Female        Agency and others
# 38309  First Degree or HND    Male        Agency and others
# 38310                  NaN    Male  Direct Internal process
# 38311  First Degree or HND    Male        Agency and others
#
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# 38307                   2           1990                     0.0
# 38308                   2           1984                     5.0
# ...

# %%
train.columns
# Out:
# Index(['EmployeeNo', 'Division', 'Qualification', 'Gender',
#        'Channel_of_Recruitment', 'Trainings_Attended', 'Year_of_birth',
#        'Last_performance_score', 'Year_of_recruitment', 'Targets_met',
#        'Previous_Award', 'Training_score_average', 'State_Of_Origin',
#        'Foreign_schooled', 'Marital_Status', 'Past_Disciplinary_Action',
#        'Previous_IntraDepartmental_Movement', 'No_of_previous_employers',
#        'Promoted_or_Not'],
#       dtype='object')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38312 entries, 0 to 38311
# Data columns (total 19 columns):
# EmployeeNo                             38312 non-null object
# Division                               38312 non-null object
# Qualification                          36633 non-null object
# Gender                                 38312 non-null object
# Channel_of_Recruitment                 38312 non-null object
# Trainings_Attended                     38312 non-null int64
# Year_of_birth                          38312 non-null int64
# Last_performance_score                 38312 non-null float64
# Year_of_recruitment                    38312 non-null int64
# Targets_met                            38312 non-null int64
# Previous_Award                         38312 non-null int64
# Training_score_average                 38312 non-null int64
# State_Of_Origin                        38312 non-null object
# Foreign_schooled                       38312 non-null object
# ...

# %% [markdown]
# We can see that our data is stored in different datatype such as int, float and text data are represented as object

# %%
#Let's take a look at the basic decription of the dataset
train.describe()
# Out:
#        Trainings_Attended  Year_of_birth  Last_performance_score  \
# count        38312.000000   38312.000000            38312.000000
# mean             2.253680    1986.209334                7.698959
# std              0.609443       7.646047                3.744135
# min              2.000000    1950.000000                0.000000
# 25%              2.000000    1982.000000                5.000000
# 50%              2.000000    1988.000000                7.500000
# 75%              2.000000    1992.000000               10.000000
# max             11.000000    2001.000000               12.500000
#
#        Year_of_recruitment   Targets_met  Previous_Award  \
# count         38312.000000  38312.000000    38312.000000
# mean           2013.139695      0.352996        0.023152
# std               4.261451      0.477908        0.150388
# min            1982.000000      0.000000        0.000000
# 25%            2012.000000      0.000000        0.000000
# ...

# %% [markdown]
# It's important to note that the describe method only works on numerical variables
#
# Things to note from the output:
# * The minimum trainings attended is 2, which means there is no employee of the firm which has not undergo training. This might mean that entry position requires training. The maximum is 11.
# * The dataset contain year of birth, we may need to create age column from it to better understand it.

# %%
#Creating age column to display the age of staff
current_year = 2020

train['Age'] = current_year - train.Year_of_birth

# %%
train.head()
# Out:
#     EmployeeNo                               Division        Qualification  \
# 0  YAK/S/00001         Commercial Sales and Marketing     MSc, MBA and PhD
# 1  YAK/S/00002  Customer Support and Field Operations  First Degree or HND
# 2  YAK/S/00003         Commercial Sales and Marketing  First Degree or HND
# 3  YAK/S/00004         Commercial Sales and Marketing  First Degree or HND
# 4  YAK/S/00006               Information and Strategy  First Degree or HND
#
#    Gender   Channel_of_Recruitment  Trainings_Attended  Year_of_birth  \
# 0  Female  Direct Internal process                   2           1986
# 1    Male        Agency and others                   2           1991
# 2    Male  Direct Internal process                   2           1987
# 3    Male        Agency and others                   3           1982
# 4    Male  Direct Internal process                   3           1990
#
#    Last_performance_score  Year_of_recruitment  Targets_met  Previous_Award  \
# ...

# %%
#We can see average age of staffs in the company
round(train['Age'].mean())
# Out:
# 34

# %% [markdown]
# Average age of staffs in the company is 33.

# %% [markdown]
# Let's explore to search for missing values in the dataset

# %%
train.isnull().sum()
# Out:
# EmployeeNo                                0
# Division                                  0
# Qualification                          1679
# Gender                                    0
# Channel_of_Recruitment                    0
# Trainings_Attended                        0
# Year_of_birth                             0
# Last_performance_score                    0
# Year_of_recruitment                       0
# Targets_met                               0
# Previous_Award                            0
# Training_score_average                    0
# State_Of_Origin                           0
# Foreign_schooled                          0
# Marital_Status                            0
# Past_Disciplinary_Action                  0
# Previous_IntraDepartmental_Movement       0
# No_of_previous_employers                  0
# Promoted_or_Not                           0
# Age                                       0
# dtype: int64

# %% [markdown]
# We have 1679 missing values in the Qualification column.
#
# Let's fill this with no qualification since we can't conjure qualification for them

# %%
train.Qualification = train.Qualification.fillna('No qualification')

# %%
#Let's explore the qualification column to see
train['Qualification'].value_counts()
# Out:
# First Degree or HND         25578
# MSc, MBA and PhD            10469
# No qualification             1679
# Non-University Education      586
# Name: Qualification, dtype: int64

# %%
train['Qualification'].hist(bins=7, grid=False, xrot=90)

# %% [markdown]
# Most staff of the company has First Degree or HND

# %%
train['Gender'].value_counts()

train['Gender'].hist(bins=3, grid=False)

# %% [markdown]
# We notice that the company has more than twice as many numbers of male staff as female staff.

# %%
train['Previous_IntraDepartmental_Movement'].value_counts()
# Out:
# No     34709
# Yes     3603
# Name: Previous_IntraDepartmental_Movement, dtype: int64

# %% [markdown]
# There has been less intradepartmental movement within the company
